# %%
import pandas as pd
from mongo_portal import mongo_find_all, mongo_insert_one, mongo_insert_many

bd = "cate"
# Mostra as colunas e linhas da base header
header = mongo_find_all(db="cate", col="header_bronze")
df_header = pd.DataFrame(header)
print(f"linhas: {len(df_header.index)}")
df_header.head(5)
# Out:
# linhas: 18
#                         _id                   _idFile _lineNumber    contrato  \
# 0  635b0aaf69a6ba7542168dfc  62fffe3650790c092a7f8dcd           3   108697000
# 1  635b0aaf69a6ba7542168dfd  63000063e6282203617a4a1c           3   108697000
# 2  635b0aaf69a6ba7542168dfe  630111a2b336dc5f51bee3b5           3   722764000
# 3  635b0aaf69a6ba7542168dff  6302b4ad7d8f3341632e5b08           3  1198444000
# 4  635b0aaf69a6ba7542168e00  6302b4adfc395e31428b925e           3  1197781000
#
#         dt_competencia numero_fatura  \
# 0  2022-08-14 21:00:00      43294838
# 1  2022-08-14 21:00:00      43294838
# 2  2022-08-19 21:00:00      43389083
# 3  2022-07-29 21:00:00      43066807
# 4  2022-07-29 21:00:00      43058991
#
#                                               _idLog  \
# 0  2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 1  2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 2  2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 3  2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 4  2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
#
#                    time_stamp
# 0  2022-10-27 19:48:05.838756
# 1  2022-10-27 19:48:05.838756
# 2  2022-10-27 19:48:05.838756
# 3  2022-10-27 19:48:05.838756
# 4  2022-10-27 19:48:05.838756

# %%
# Mostra os tipos de dados de cada coluna
df_header.dtypes
# Out:
# _id               object
# _idFile           object
# _lineNumber       object
# contrato          object
# dt_competencia    object
# numero_fatura     object
# _idLog            object
# time_stamp        object
# dtype: object

# %%
# Transforma o numero_fatura e contrato em número
df_header["numero_fatura"] = pd.to_numeric(df_header["numero_fatura"])
df_header["contrato"] = pd.to_numeric(df_header["contrato"])
df_header.dtypes
# Out:
# _id               object
# _idFile           object
# _lineNumber       object
# contrato           int64
# dt_competencia    object
# numero_fatura      int64
# _idLog            object
# time_stamp        object
# dtype: object

# %%
# Verifica se tem algum valor nulo
df_header.isnull().sum()
# Out:
# _id               0
# _idFile           0
# _lineNumber       0
# contrato          0
# dt_competencia    0
# numero_fatura     0
# _idLog            0
# time_stamp        0
# dtype: int64

# %%
# Mostra as colunas e linhas da base mensalidade
mensalidade = mongo_find_all(db="cate", col="mensalidade_bronze")
df_mensalidade = pd.DataFrame(mensalidade)
print(f"linhas: {len(df_mensalidade.index)}")
df_mensalidade.head(5)
# Out:
# linhas: 136
#                         _id                   _idFile  \
# 0  62fffee87c45476c4844c3a8  62fffe3650790c092a7f8dcd
# 1  62fffee87c45476c4844c3a9  62fffe3650790c092a7f8dcd
# 2  62fffee87c45476c4844c3aa  62fffe3650790c092a7f8dcd
# 3  630000d519f2f821f3915ac3  63000063e6282203617a4a1c
# 4  630000d519f2f821f3915ac4  63000063e6282203617a4a1c
#
#            _idheader_bronze          dt_inclusao marca_otica  \
# 0  62fffee77c45476c4844c3a7  2015-09-30 21:00:00   291305148
# 1  62fffee77c45476c4844c3a7  2016-03-31 21:00:00   291441203
# 2  62fffee77c45476c4844c3a7  2016-04-30 21:00:00   291469272
# 3  630000d519f2f821f3915ac2  2015-09-30 21:00:00   291305148
# 4  630000d519f2f821f3915ac2  2016-03-31 21:00:00   291441203
#
#                           nXmX_bXnXfiWiXriX outros outros_orig  \
# 0                       MXRWXLLX WXNTXFXNTI      0         0.0
# 1            JXIWX XRIWX DX XNDRXDX DX ILVX      0         0.0
# 2  MXRIX BXNIGNX XLIVXIRX DX NXWIMXNTX JUWX      0         0.0
# 3                       MXRWXLLX WXNTXFXNTI      0         0.0
# 4            JXIWX XRIWX DX XNDRXDX DX ILVX      0         0.0
#
#                          plano                              rubrica  \
# 0  AMIL 700 QP NACIONAL R PJCA  Mens. Titular Faixa Etária Implant.
# 1  AMIL 400 QP NACIONAL R PJCA  Mens. Titular Faixa Etária Implant.
# 2  AMIL 400 QP NACIONAL R PJCA  Mens. Titular Faixa Etária Implant.
# 3  AMIL 700 QP NACIONAL R PJCA  Mens. Titular Faixa Etária Implant.
# 4  AMIL 400 QP NACIONAL R PJCA  Mens. Titular Faixa Etária Implant.
#
#   tp_beneficiario valor_orig  \
# 0               T    3892.76
# 1               T    2834.42
# 2               T    8525.43
# 3               T    3892.76
# 4               T    2834.42
#
#                                               _idLog  \
# 0  2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 1  2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 2  2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 3  2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 4  2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
#
#                    time_stamp
# 0  2022-10-27 19:48:05.930512
# 1  2022-10-27 19:48:05.930512
# 2  2022-10-27 19:48:05.930512
# 3  2022-10-27 19:48:05.930512
# 4  2022-10-27 19:48:05.930512

# %%
df_mensalidade.dtypes
# Out:
# _id                  object
# _idFile              object
# _idheader_bronze     object
# dt_inclusao          object
# marca_otica          object
# nXmX_bXnXfiWiXriX    object
# outros               object
# outros_orig          object
# plano                object
# rubrica              object
# tp_beneficiario      object
# valor_orig           object
# _idLog               object
# time_stamp           object
# dtype: object

# %%
# Transforma algumas colunas em número
df_mensalidade["marca_otica"] = pd.to_numeric(df_mensalidade["marca_otica"])
df_mensalidade["valor_orig"] = pd.to_numeric(df_mensalidade["valor_orig"])
df_mensalidade.dtypes
# Out:
# _id                   object
# _idFile               object
# _idheader_bronze      object
# dt_inclusao           object
# marca_otica            int64
# nXmX_bXnXfiWiXriX     object
# outros                object
# outros_orig           object
# plano                 object
# rubrica               object
# tp_beneficiario       object
# valor_orig           float64
# _idLog                object
# time_stamp            object
# dtype: object

# %%
# Verifica se tem algum valor nulo
df_mensalidade.isnull().sum()
# Out:
# _id                  0
# _idFile              0
# _idheader_bronze     0
# dt_inclusao          0
# marca_otica          0
# nXmX_bXnXfiWiXriX    0
# outros               0
# outros_orig          0
# plano                0
# rubrica              0
# tp_beneficiario      0
# valor_orig           0
# _idLog               0
# time_stamp           0
# dtype: int64

# %%
# Une as duas bases usando o _idFile
df_header_mensalidade = pd.merge(df_header, df_mensalidade, on="_idFile")
print(f"linhas: {len(df_header_mensalidade.index)}")
df_header_mensalidade.isnull().sum()
# Out:
# linhas: 136
# _id_x                0
# _idFile              0
# _lineNumber          0
# contrato             0
# dt_competencia       0
# numero_fatura        0
# _idLog_x             0
# time_stamp_x         0
# _id_y                0
# _idheader_bronze     0
# dt_inclusao          0
# marca_otica          0
# nXmX_bXnXfiWiXriX    0
# outros               0
# outros_orig          0
# plano                0
# rubrica              0
# tp_beneficiario      0
# valor_orig           0
# _idLog_y             0
# time_stamp_y         0
# dtype: int64

# %%
# Mostra repetições
print(f"qtd de marca_otica contando repetições: {df_header_mensalidade['marca_otica'].value_counts().sum()}")
df_header_mensalidade["marca_otica"].value_counts().head(15)
# Out:
# qtd de marca_otica contando repetições: 136
# 291305148    3
# 291469272    3
# 291441203    3
# 76100372     2
# 131427024    2
# 131570927    2
# 76100373     2
# 84162731     2
# 81   6302b525171b4e38d1b83f07  ...           XNDRXX GXUVXIX RIBXIRX TXIXXIRX
# 82   6302b525171b4e38d1b83f07  ...           XNDRXX GXUVXIX RIBXIRX TXIXXIRX
# 87   6302c799809be80ea0bc1f83  ...                     HXLXNX LXPX WXRVXLHXL
# 88   6302c799809be80ea0bc1f83  ...                     HXLXNX LXPX WXRVXLHXL
# 130  6305270dc850d94498f1b603  ...                       MXRWXLLX WXNTXFXNTI
# 131  6305270dc850d94498f1b603  ...            JXIWX XRIWX DX XNDRXDX DX ILVX
# 132  6305270dc850d94498f1b603  ...  MXRIX BXNIGNX XLIVXIRX DX NXWIMXNTX JUWX
#
#      outros outros_orig                          plano  \
# 0         0         0.0    AMIL 700 QP NACIONAL R PJCA
# 1         0         0.0    AMIL 400 QP NACIONAL R PJCA
# 2         0         0.0    AMIL 400 QP NACIONAL R PJCA
# 3         0         0.0    AMIL 700 QP NACIONAL R PJCA
# 4         0         0.0    AMIL 400 QP NACIONAL R PJCA
# 5         0         0.0    AMIL 400 QP NACIONAL R PJCA
# 7         0         0.0  MEDICUS QC 122 PARTICIP. - RN
# 8         0         0.0  MEDICUS QC 122 PARTICIP. - RN
# 38        0         0.0  MEDICUS QC 122 PARTICIP. - RN
# 39        0         0.0  MEDICUS QC 122 PARTICIP. - RN
# 42        0         0.0  MEDICUS QC 122 PARTICIP. - RN
# 43        0         0.0  MEDICUS QC 122 PARTICIP. - RN
# 47        0         0.0  MEDICUS QC 122 PARTICIP. - RN
# 48        0         0.0  MEDICUS QC 122 PARTICIP. - RN
# 79        0         0.0     NEXT MUN SÃO PAULO QC PJCA
# 80    26084      260.84     NEXT MUN SÃO PAULO QC PJCA
# 81        0         0.0     NEXT MUN SÃO PAULO QC PJCA
# 82    64145      641.45     NEXT MUN SÃO PAULO QC PJCA
# 87        0         0.0    AMIL 500 QP NACIONAL R PJCA
# 88    42972      429.72    AMIL 500 QP NACIONAL R PJCA
# 130       0         0.0    AMIL 700 QP NACIONAL R PJCA
# 131       0         0.0    AMIL 400 QP NACIONAL R PJCA
# 132       0         0.0    AMIL 400 QP NACIONAL R PJCA
#
#                                  rubrica tp_beneficiario valor_orig  \
# 0    Mens. Titular Faixa Etária Implant.               T    3892.76
# 1    Mens. Titular Faixa Etária Implant.               T    2834.42
# 2    Mens. Titular Faixa Etária Implant.               T    8525.43
# 3    Mens. Titular Faixa Etária Implant.               T    3892.76
# 4    Mens. Titular Faixa Etária Implant.               T    2834.42
# 5    Mens. Titular Faixa Etária Implant.               T    8525.43
# 7    Mens. Titular Faixa Etária Implant.               T    1738.03
# 8                        Co-participação               T       0.00
# 38              Mens. Titular Per Capita               T     733.99
# 39                       Co-participação               T       0.00
# 42   Mens. Titular Faixa Etária Implant.               T     709.48
# 43                       Co-participação               T       0.00
# 47   Mens. Titular Faixa Etária Implant.               T     709.48
# 48                       Co-participação               T       0.00
# 79   Mens. Titular Faixa Etária Implant.               T     416.82
# 80          Cobrança Inclusão Retroativa               T       0.00
# 81   Mens. Depend. Faixa Etária Implant.               D    1223.89
# 82          Cobrança Inclusão Retroativa               D       0.00
# 87   Mens. Depend. Faixa Etária Implant.               D    1287.56
# 88          Cobrança Inclusão Retroativa               D       0.00
# 130  Mens. Titular Faixa Etária Implant.               T    3892.76
# 131  Mens. Titular Faixa Etária Implant.               T    2834.42
# 132  Mens. Titular Faixa Etária Implant.               T    8525.43
#
#                                               _idLog_y  \
# 0    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 1    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 2    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 3    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 4    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 5    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 7    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 8    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 38   2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 39   2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 42   2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 43   2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 47   2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 48   2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 79   2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 80   2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 81   2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 82   2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 87   2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 88   2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 130  2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 131  2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 132  2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
#
#                    time_stamp_y                         resultado
# 0    2022-10-27 19:48:05.930512  mensalidade_marca_otica_repetida
# 1    2022-10-27 19:48:05.930512  mensalidade_marca_otica_repetida
# 2    2022-10-27 19:48:05.930512  mensalidade_marca_otica_repetida
# 3    2022-10-27 19:48:05.930512  mensalidade_marca_otica_repetida
# 4    2022-10-27 19:48:05.930512  mensalidade_marca_otica_repetida
# 5    2022-10-27 19:48:05.930512  mensalidade_marca_otica_repetida
# 7    2022-10-27 19:48:05.930512  mensalidade_marca_otica_repetida
# 8    2022-10-27 19:48:05.930512  mensalidade_marca_otica_repetida
# 38   2022-10-27 19:48:05.930512  mensalidade_marca_otica_repetida
# 39   2022-10-27 19:48:05.930512  mensalidade_marca_otica_repetida
# 42   2022-10-27 19:48:05.930512  mensalidade_marca_otica_repetida
# 43   2022-10-27 19:48:05.930512  mensalidade_marca_otica_repetida
# 47   2022-10-27 19:48:05.930512  mensalidade_marca_otica_repetida
# 48   2022-10-27 19:48:05.930512  mensalidade_marca_otica_repetida
# 79   2022-10-27 19:48:05.930512  mensalidade_marca_otica_repetida
# 80   2022-10-27 19:48:05.930512  mensalidade_marca_otica_repetida
# 81   2022-10-27 19:48:05.930512  mensalidade_marca_otica_repetida
# 82   2022-10-27 19:48:05.930512  mensalidade_marca_otica_repetida
# 87   2022-10-27 19:48:05.930512  mensalidade_marca_otica_repetida
# 88   2022-10-27 19:48:05.930512  mensalidade_marca_otica_repetida
# 130  2022-10-27 19:48:05.930512  mensalidade_marca_otica_repetida
# 131  2022-10-27 19:48:05.930512  mensalidade_marca_otica_repetida
# 132  2022-10-27 19:48:05.930512  mensalidade_marca_otica_repetida
#
# [23 rows x 22 columns]

# %%
# Transforma a marca_otica no index e remove suas repetições, deixando no mínimo 1 de cada
df_header_mensalidade_umarca = df_header_mensalidade.groupby("marca_otica").nth[0]
df_header_mensalidade_umarca.index.value_counts()
# Out:
# 73391747     1
# 131743767    1
# 131702254    1
# 131702114    1
# 131695479    1
#             ..
# 76100373     1
# 76100372     1
# 76100317     1
# 76100313     1
# 852308507    1
# Name: marca_otica, Length: 123, dtype: int64

# %%
# Mostra as colunas e qtd de linhas da base repasse
repasse = mongo_find_all(db="cate", col="repasse_bronze")
df_repasse = pd.DataFrame(repasse)
print(f"linhas: {len(df_repasse.index)}")
df_repasse.head(5)
# Out:
# linhas: 1080
#                         _id boleto_1 boleto_2 boleto_3  cod_contrato  \
# 0  635b0acf69a6ba7542168e10      NÃO      NÃO      NÃO  1189455000.0
# 1  635b0acf69a6ba7542168e11      NÃO      NÃO      NÃO  1189442000.0
# 2  635b0acf69a6ba7542168e12      NÃO      NÃO      NÃO           nan
# 3  635b0acf69a6ba7542168e13      NÃO      NÃO      NÃO           nan
# 4  635b0acf69a6ba7542168e14      NÃO      NÃO      NÃO  1189449000.0
#
#   codigo_convenio codigo_plano codigo_produto codigo_segurado  \
# 0              19            0              1          163397
# 1              57            0              1          165996
# 2              19            0              1          175878
# 3             278            0              1          186475
# 4              19            0              1          214512
#
#            competencia  ... odonto_str operadora parcela_1  \
# 0  2022-08-04 21:00:00  ...          0      AMIL       nan
# 1  2022-08-04 21:00:00  ...          0      AMIL       nan
# 2  2022-08-04 21:00:00  ...          0      AMIL       nan
# 3  2022-08-04 21:00:00  ...          0      AMIL       nan
# 4  2022-08-04 21:00:00  ...          0      AMIL       nan
#
#                       plano   saude saude_net_orig saude_orig situacao  \
# 0      AMIL 400 QP NACIONAL   10991         923.24     1099.1  INATIVO
# 1           NEXT PLUS RM RJ  103421         868.74    1034.21  INATIVO
# 2           NEXT PLUS RM RJ   30312          254.6     303.12  INATIVO
# 3      AMIL 500 QP NACIONAL  199162        1653.03    1991.62  INATIVO
# 4  NEXT MUNICIPAL SÃO PAULO   31052         260.84     310.52  INATIVO
#
#                                               _idLog  \
# 0  2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 1  2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 2  2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 3  2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 4  2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
#
#                    time_stamp
# 0  2022-10-27 19:48:06.473955
# 1  2022-10-27 19:48:06.473955
# 2  2022-10-27 19:48:06.473955
# 3  2022-10-27 19:48:06.473955
# 4  2022-10-27 19:48:06.473955
#
# [5 rows x 36 columns]

# %%
df_repasse.dtypes
# Out:
# _id                   object
# boleto_1              object
# boleto_2              object
# boleto_3              object
# cod_contrato          object
# codigo_convenio       object
# codigo_plano          object
# codigo_produto        object
# codigo_segurado       object
# competencia           object
# convenio              object
# dependente            object
# dt_cancelamento       object
# dt_geracao            object
# dt_nascimento         object
# dt_situacao           object
# dt_suspensao          object
# inicio_vigencia       object
# marca_otica           object
# marca_otica_odonto    object
# nXmX_bXnXfXWXXrXX     object
# odonto                object
# odonto_net            object
# odonto_net_orig       object
# odonto_net_str        object
# odonto_orig           object
# odonto_str            object
# operadora             object
# parcela_1             object
# plano                 object
# saude                 object
# saude_net_orig        object
# saude_orig            object
# situacao              object
# _idLog                object
# time_stamp            object
# dtype: object

# %%
# Transforma algumas colunas em número
df_repasse["codigo_convenio"] = pd.to_numeric(df_repasse["codigo_convenio"])
df_repasse["codigo_plano"] = pd.to_numeric(df_repasse["codigo_plano"])
df_repasse["marca_otica"] = pd.to_numeric(df_repasse["marca_otica"])
df_repasse["saude_net_orig"] = pd.to_numeric(df_repasse["saude_net_orig"])
df_repasse.dtypes
# Out:
# _id                    object
# boleto_1               object
# boleto_2               object
# boleto_3               object
# cod_contrato           object
# codigo_convenio         int64
# codigo_plano            int64
# codigo_produto         object
# codigo_segurado        object
# competencia            object
# convenio               object
# dependente             object
# dt_cancelamento        object
# dt_geracao             object
# dt_nascimento          object
# dt_situacao            object
# dt_suspensao           object
# inicio_vigencia        object
# marca_otica             int64
# marca_otica_odonto     object
# nXmX_bXnXfXWXXrXX      object
# odonto                 object
# odonto_net             object
# odonto_net_orig        object
# odonto_net_str         object
# odonto_orig            object
# odonto_str             object
# operadora              object
# parcela_1              object
# plano                  object
# saude                  object
# saude_net_orig        float64
# saude_orig             object
# situacao               object
# _idLog                 object
# time_stamp             object
# dtype: object

# %%
# Separa as linhas repetidas, mantendo pelo menos um registro das repetições
mask = df_repasse.marca_otica.duplicated()
print(f"Linhas repetidas: {len(df_repasse[mask])}")
print(f"Linhas únicas: {len(df_repasse[~mask])}")
df_repasse_u = df_repasse[~mask].copy()
# Out:
# Linhas repetidas: 534
# Linhas únicas: 546

# %%
# Analisa a coluna de contrato
df_repasse_u["cod_contrato"].value_counts()
# Out:
# nan             349
# 1189455000.0     43
# 1189426000.0     22
# 1189449000.0     13
# 108739000.0      10
# 1191011000.0     10
# 1189435000.0      8
# 0.0               8
# 310572000.0       7
# 326288000.0       6
# 927614000.0       5
# 1201671000.0      5
# 318048000.0       5
# 1191014000.0      5
# 927627000.0       4
# 927632000.0       4
# 1201881000.0      4
# 1189459000.0      4
# 1189442000.0      3
# 927616000.0       3
# 311084000.0       3
# 108697000.0       3
# 927223000.0       2
# 310603000.0       2
# 938494000.0       2
# 927630000.0       2
# 927264000.0       2
# 1189445000.0      2
# 336362000.0       2
# 310453000.0       2
# 320087000.0       1
# 1190477000.0      1
# 15033000.0        1
# 310450000.0       1
# 1189029000.0      1
# 326376000.0       1
# Name: cod_contrato, dtype: int64

# %%
# Remove as linhas sem contrato ou com valor 0
#dados_insuficientes = df_repasse_u[df_repasse_u.cod_contrato == "nan"]
df = df_repasse_u.loc[df_repasse_u["cod_contrato"].isin(["nan", "0.0"])]
df["resultado"] = "dados_insuficientes"
df
mongo_insert_many(df.to_dict("records"), db=bd, col="h_m_r_silver")
df_repasse_u = df_repasse_u[df_repasse_u.cod_contrato != "nan"]
df_repasse_u = df_repasse_u[df_repasse_u.cod_contrato != "0.0"]
print(f"linhas: {len(df_repasse_u.index)}")
df_repasse_u["cod_contrato"].value_counts()
# Out:
# C:\Users\junio\AppData\Local\Temp\ipykernel_4948\2283243766.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["resultado"] = "dados_insuficientes"
# linhas: 189
# 1189455000.0    43
# 1189426000.0    22
# 1189449000.0    13
# 1191011000.0    10
# 108739000.0     10
# 1189435000.0     8
# 310572000.0      7
# 326288000.0      6
# 927614000.0      5
# 318048000.0      5
# 1201671000.0     5
# 1191014000.0     5
# 927627000.0      4
# 1189459000.0     4
# 1201881000.0     4
# 927632000.0      4
# 311084000.0      3
# 927616000.0      3
# 1189442000.0     3
# 108697000.0      3
# 310603000.0      2
# 927223000.0      2
# 927630000.0      2
# 938494000.0      2
# 927264000.0      2
# 1189445000.0     2
# 336362000.0      2
# 310453000.0      2
# 1189029000.0     1
# 15033000.0       1
# 320087000.0      1
# 310450000.0      1
# 1190477000.0     1
# 326376000.0      1
# Name: cod_contrato, dtype: int64

# %%
df_repasse_u["cod_contrato"] = pd.to_numeric(df_repasse_u["cod_contrato"])
df_repasse_u.dtypes
# Out:
# _id                    object
# boleto_1               object
# boleto_2               object
# boleto_3               object
# cod_contrato          float64
# codigo_convenio         int64
# codigo_plano            int64
# codigo_produto         object
# codigo_segurado        object
# competencia            object
# convenio               object
# dependente             object
# dt_cancelamento        object
# dt_geracao             object
# dt_nascimento          object
# dt_situacao            object
# dt_suspensao           object
# inicio_vigencia        object
# marca_otica             int64
# marca_otica_odonto     object
# nXmX_bXnXfXWXXrXX      object
# odonto                 object
# odonto_net             object
# odonto_net_orig        object
# odonto_net_str         object
# odonto_orig            object
# odonto_str             object
# operadora              object
# parcela_1              object
# plano                  object
# saude                  object
# saude_net_orig        float64
# saude_orig             object
# situacao               object
# _idLog                 object
# time_stamp             object
# dtype: object

# %%
# Verifica se a marca_otica do repasse está presente no cruzamento header_mensalidade
counter = 0
marcas_match = []
for marca_repasse in df_repasse_u["marca_otica"]:
    if marca_repasse in df_header_mensalidade_umarca.index:    # marca_otica presente na header_mensalidade
        counter += 1
        marcas_match.append(marca_repasse)
print(marcas_match)
print(f"qtd de marca_otica que deu match: {counter}")
# Out:
# [291093370, 291139507, 78372767, 291214061, 291238688, 291263194, 291285783, 291305148, 291441203, 291469272, 291052304, 852199546, 852308507, 291191630, 84162731, 75018205]
# qtd de marca_otica que deu match: 16

# %%
# Deixa separado em um novo df apenas as linhas com marca_otica que deu match
match = df_repasse_u["marca_otica"].isin(marcas_match)
df = df_repasse_u.copy()[~match]
df["resultado"] = "somente_repasse"
mongo_insert_many(df.to_dict("records"), db=bd, col="h_m_r_silver")
df_repasse_m = df_repasse_u.copy()[match]
df_repasse_m["marca_otica"].value_counts()
# Out:
# 291093370    1
# 291139507    1
# 78372767     1
# 291214061    1
# 291238688    1
# 291263194    1
# 291285783    1
# 291305148    1
# 291441203    1
# 291469272    1
# 291052304    1
# 852199546    1
# 852308507    1
# 291191630    1
# 84162731     1
# 75018205     1
# Name: marca_otica, dtype: int64

# %%
# Verifica os cod_contrato que estão presentes na base header_mensalidade
counter = 0
contrato_unmatch = []
contrato_match = []
for contrato_repasse in df_repasse_m["cod_contrato"]:
    search = df_header_mensalidade[df_header_mensalidade["contrato"] == contrato_repasse]
    if len(search.isnull().values) >= 1:
        counter += 1
        if contrato_repasse not in contrato_match:
            contrato_match.append(contrato_repasse)
    else:
        if contrato_repasse not in contrato_unmatch:
            contrato_unmatch.append(contrato_repasse)
print(contrato_unmatch)
print(f"qtd de match: {counter}")
# Out:
# [1189445000.0, 1191014000.0]
# qtd de match: 14

# %%
# Separa em um df apenas os matches de contrato
match = df_repasse_m["cod_contrato"].isin(contrato_match)
df = df_repasse_m.copy()[~match]
df["resultado"] = "somente_repasse"
mongo_insert_many(df.to_dict("records"), db=bd, col="h_m_r_silver")
df_repasse_f = df_repasse_m.copy()[match]
df_repasse_f["cod_contrato"]
# Out:
# 19    310572000.0
# 20    310572000.0
# 21    310572000.0
# 22    310572000.0
# 23    310572000.0
# 24    310572000.0
# 25    310572000.0
# 26    108697000.0
# 28    108697000.0
# 29    108697000.0
# 33    318048000.0
# 35    311084000.0
# 37    311084000.0
# 38    318048000.0
# Name: cod_contrato, dtype: float64

# %%
# Une as base header_mensalidade com a repasse
df_repasse_umarca = df_repasse_f.groupby("marca_otica").nth(0)
df_h_m_r = pd.merge(df_header_mensalidade_umarca, df_repasse_umarca, on="marca_otica")
df_h_m_r
# Out:
#                                 _id_x                   _idFile _lineNumber  \
# marca_otica
# 78372767     635b0aaf69a6ba7542168e06  630520e93299fb8245e2ee5d           3
# 291052304    635b0aaf69a6ba7542168e0b  630520ea89a0eceb5649c1c7           3
# 291093370    635b0aaf69a6ba7542168e06  630520e93299fb8245e2ee5d           3
# 291139507    635b0aaf69a6ba7542168e06  630520e93299fb8245e2ee5d           3
# 291191630    635b0aaf69a6ba7542168e0b  630520ea89a0eceb5649c1c7           3
# 291214061    635b0aaf69a6ba7542168e06  630520e93299fb8245e2ee5d           3
# 291238688    635b0aaf69a6ba7542168e06  630520e93299fb8245e2ee5d           3
# 291263194    635b0aaf69a6ba7542168e06  630520e93299fb8245e2ee5d           3
# 291285783    635b0aaf69a6ba7542168e06  630520e93299fb8245e2ee5d           3
# 291305148    635b0aaf69a6ba7542168dfc  62fffe3650790c092a7f8dcd           3
# 291441203    635b0aaf69a6ba7542168dfc  62fffe3650790c092a7f8dcd           3
# 291469272    635b0aaf69a6ba7542168dfc  62fffe3650790c092a7f8dcd           3
# 852199546    635b0aaf69a6ba7542168e0d  630520ea7e0aa107bbd349b9           3
# 852308507    635b0aaf69a6ba7542168e0d  630520ea7e0aa107bbd349b9           3
#
#               contrato       dt_competencia  numero_fatura  \
# marca_otica
# 78372767     310572000  2022-08-14 21:00:00       43295208
# 291052304    318048000  2022-08-14 21:00:00       43295857
# 291093370    310572000  2022-08-14 21:00:00       43295208
# 291139507    310572000  2022-08-14 21:00:00       43295208
# 291191630    318048000  2022-08-14 21:00:00       43295857
# 291214061    310572000  2022-08-14 21:00:00       43295208
# 291238688    310572000  2022-08-14 21:00:00       43295208
# 291263194    310572000  2022-08-14 21:00:00       43295208
# 291285783    310572000  2022-08-14 21:00:00       43295208
# 291305148    108697000  2022-08-14 21:00:00       43294838
# 291441203    108697000  2022-08-14 21:00:00       43294838
# 291469272    108697000  2022-08-14 21:00:00       43294838
# 852199546    311084000  2022-08-14 21:00:00        1104591
# 852308507    311084000  2022-08-14 21:00:00        1104591
#
#                                                       _idLog_x  \
# marca_otica
# 78372767     2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 
# 852308507               GP3 - BLUE PLUS 300 QP  169348        1498.64
#
#             saude_orig  situacao  \
# marca_otica
# 78372767        1917.9     ATIVO
# 291052304      2086.19     ATIVO
# 291093370      2242.06   INATIVO
# 291139507       3288.3     ATIVO
# 291191630      2139.79     ATIVO
# 291214061      4052.46   INATIVO
# 291238688      2466.15     ATIVO
# 291263194      2656.36     ATIVO
# 291285783      5873.21     ATIVO
# 291305148      4398.83     ATIVO
# 291441203      3202.92   INATIVO
# 291469272      9633.78     ATIVO
# 852199546      1693.48     ATIVO
# 852308507      1693.48     ATIVO
#
#                                                         _idLog  \
# marca_otica
# 78372767     2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 291052304    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 291093370    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 291139507    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 291191630    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 291214061    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 291238688    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 291263194    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 291285783    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 291305148    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 291441203    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 291469272    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 852199546    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 852308507    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
#
#                              time_stamp
# marca_otica
# 78372767     2022-10-27 19:48:06.473955
# 291052304    2022-10-27 19:48:06.473955
# 291093370    2022-10-27 19:48:06.473955
# 291139507    2022-10-27 19:48:06.473955
# 291191630    2022-10-27 19:48:06.473955
# 291214061    2022-10-27 19:48:06.473955
# 291238688    2022-10-27 19:48:06.473955
# 291263194    2022-10-27 19:48:06.473955
# 291285783    2022-10-27 19:48:06.473955
# 291305148    2022-10-27 19:48:06.473955
# 291441203    2022-10-27 19:48:06.473955
# 291469272    2022-10-27 19:48:06.473955
# 852199546    2022-10-27 19:48:06.473955
# 852308507    2022-10-27 19:48:06.473955
#
# [14 rows x 55 columns]

# %%
# Verifica as linhas que estavam no header_mensalidade mas não estavam no repasse
counter = 0
marcas_lost = []
df = df_header_mensalidade_umarca.reset_index(level=0)
for i in df_header_mensalidade_umarca.index:
    if i not in df_h_m_r.index:
        marcas_lost.append(i)
    counter +=1
print(marcas_lost)
print(f"qtd de linhas perdidas: {len(marcas_lost)}")
# Out:
# [73391747, 73394844, 73599828, 73611845, 73611877, 73611883, 73799319, 73811692, 74065782, 74065788, 74075133, 74081697, 74081768, 74090462, 74090463, 74090737, 74325051, 74543375, 74543416, 74766979, 74766980, 74766989, 74770467, 74773677, 74953220, 74953325, 74956673, 74958124, 75018205, 75187990, 75188813, 76090758, 76090759, 76100313, 76100317, 76100372, 76100373, 76100983, 76290913, 76662253, 76663439, 76663612, 76663637, 84162731, 131064185, 131064525, 131064614, 131065017, 131065050, 131065181, 131065190, 131065840, 131065858, 131065947, 131066081, 131066633, 131066641, 131066650, 131066749, 131160249, 131160346, 131160354, 131160371, 131160401, 131160427, 131160435, 131160451, 131172476, 131226649, 131226746, 131227360, 131236822, 131285637, 131311786, 131341294, 131341341, 131419021, 131427024, 131444255, 131444298, 131563190, 131570927, 131572598, 131607031, 131616978, 131648594, 131695436, 131695479, 131702114, 131702254, 131738020, 131743767, 131744241, 131756117, 133301630, 290951119, 291026931, 291111408, 291139515, 291214070, 291305555, 291396003, 291417728, 291469310, 291486169, 291503802, 291554270, 851831940, 852199538]
# qtd de linhas perdidas: 109

# %%
# Insere no mongo
match = df["marca_otica"].isin(marcas_lost)
df = df[match]
df["resultado"] = "somente_mensalidade"
mongo_insert_many(df.to_dict("records"), db=bd, col="h_m_r_silver")
df
# Out:
#      marca_otica                     _id_x                   _idFile  \
# 0       73391747  635b0aaf69a6ba7542168e01  6302b4ad8382b804d9a3ac35
# 1       73394844  635b0aaf69a6ba7542168e00  6302b4adfc395e31428b925e
# 2       73599828  635b0aaf69a6ba7542168e01  6302b4ad8382b804d9a3ac35
# 3       73611845  635b0aaf69a6ba7542168e05  6302b4ad14af7051a26da0b6
# 4       73611877  635b0aaf69a6ba7542168dff  6302b4ad7d8f3341632e5b08
# ..           ...                       ...                       ...
# 116    291486169  635b0aaf69a6ba7542168e07  630520e957663d50f553f459
# 117    291503802  635b0aaf69a6ba7542168e06  630520e93299fb8245e2ee5d
# 118    291554270  635b0aaf69a6ba7542168e07  630520e957663d50f553f459
# 119    851831940  635b0aaf69a6ba7542168e09  630520ea612e637c93d8bb09
# 120    852199538  635b0aaf69a6ba7542168e0d  630520ea7e0aa107bbd349b9
#
#     _lineNumber    contrato       dt_competencia  numero_fatura  \
# 0             3  1198447000  2022-07-29 21:00:00       43059296
# 1             3  1197781000  2022-07-29 21:00:00       43058991
# 2             3  1198447000  2022-07-29 21:00:00       43059296
# 3             3  1198467000  2022-07-29 21:00:00       43059282
# 4             3  1198444000  2022-07-29 21:00:00       43066807
# ..          ...         ...                  ...            ...
# 116           3   189733000  2022-08-14 21:00:00       43295864
# 117           3   310572000  2022-08-14 21:00:00       43295208
# 118           3   189733000  2022-08-14 21:00:00       43295864
# 119           3   320087000  2022-08-14 21:00:00        1104601
# 120           3   311084000  2022-08-14 21:00:00        1104591
#
#                                               _idLog_x  \
# 0    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 1    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 2    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 3    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 4    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# ..                                                 ...
# 116  2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 117  2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 118  2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 119  2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 120  2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
#
#                    time_stamp_x                     _id_y  ...  \
# 0    2022-10-27 19:48:05.838756  6302c877dc774878504ce9bd  ...
# 1    2022-10-27 19:48:05.838756  6302c799809be80ea0bc1f84  ...
# 2    2022-10-27 19:48:05.838756  6302c877dc774878504ce9be  ...
# 3    2022-10-27 19:48:05.838756  6302cc283138135946ebe370  ...
# 4    2022-10-27 19:48:05.838756  6302b525171b4e38d1b83f08  ...
# ..                          ...                       ...  ...
# 116  2022-10-27 19:48:05.838756  630522006ce5ce76ca41534d  ...
# 117  2022-10-27 19:48:05.838756  630521961e74c614e130cd9b  ...
# 118  2022-10-27 19:48:05.838756  630522006ce5ce76ca41534e  ...
# 119  2022-10-27 19:48:05.838756  630523fabdc00722c3865634  ...
# 120  2022-10-27 19:48:05.838756  630527e3bae0582dc78cfc40  ...
#
#                   nXmX_bXnXfiWiXriX outros outros_orig  \
# 0        GIXLX RXBXLX WXLDXIRX LXRX      0         0.0
# 1              PRIWILX DX ILVX LXPX      0         0.0
# 2                 RXWXLTXN DX NXVXX      0         0.0
# 3        LXURX LIZ PXULX FIGUXIRXDX      0         0.0
# 4    GXBRIXLX RXDRIGUX XUFRXIX MXTX      0         0.0
# ..                              ...    ...         ...
# 116           MIGUXL DX XUZX BXRBXX      0         0.0
# 117          RITX FXRRXIRX XLIVXIRX      0         0.0
# 118  GIXVXNNX WXRVXLHX DX NXWIMXNTX      0         0.0
# 119    XDNX MXRIX PXZ WXTXLX BRXNWX      0         0.0
# 120     JXXX GUILHXRMX RUBXM XGUIXR      0         0.0
#
#                                   plano                              rubrica  \
# 0           AMIL 400 QC NACIONAL R PJCA  Mens. Titular Faixa Etária Implant.
# 1           AMIL 500 QP NACIONAL R PJCA  Mens. Titular Faixa Etária Implant.
# 2           AMIL 500 QP NACIONAL R PJCA  Mens. Titular Faixa Etária Implant.
# 3    AMIL 400 QC NACIONAL R COPART PJCA  Mens. Titular Faixa Etária Implant.
# 4            NEXT MUN SÃO PAULO QC PJCA  Mens. Titular Faixa Etária Implant.
# ..                                  ...                                  ...
# 116         AMIL 400 QP NACIONAL R PJCA  Mens. Titular Faixa Etária Implant.
# 117         BLUE 400 PLUS NAC QP PJCA R             Mens. Titular Per Capita
# 118         AMIL 400 QC NACIONAL R PJCA  Mens. Titular Faixa Etária Implant.
# 119         BLUE 300 PLUS NAC QC PJCA R             Mens. Titular Per Capita
# 120         BLUE 300 PLUS NAC QP PJCA R  Mens. Titular Faixa Etária Implant.
#
#     tp_beneficiario valor_orig  \
# 0                 T    2060.81
# 1                 T    2323.64
# 2                 T    2323.64
# 3                 T    1103.04
# 4                 T     416.82
# ..              ...        ...
# 116               T    1670.58
# 117               T    8284.03
# 118               T    1469.36
# 119               T    5651.65
# 120               T    1498.64
#
#                                               _idLog_y  \
# 0    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 1    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 2    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 3    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 4    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# ..                                                 ...
# 116  2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 117  2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 118  2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 119  2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 120  2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
#
#                    time_stamp_y            resultado
# 0    2022-10-27 19:48:05.930512  somente_mensalidade
# 1    2022-10-27 19:48:05.930512  somente_mensalidade
# 2    2022-10-27 19:48:05.930512  somente_mensalidade
# 3    2022-10-27 19:48:05.930512  somente_mensalidade
# 4    2022-10-27 19:48:05.930512  somente_mensalidade
# ..                          ...                  ...
# 116  2022-10-27 19:48:05.930512  somente_mensalidade
# 117  2022-10-27 19:48:05.930512  somente_mensalidade
# 118  2022-10-27 19:48:05.930512  somente_mensalidade
# 119  2022-10-27 19:48:05.930512  somente_mensalidade
# 120  2022-10-27 19:48:05.930512  somente_mensalidade
#
# [109 rows x 22 columns]

# %%
# Analisa se o contrato da match, afinal eles são os campos chave entre header e repasse
# Salva num dict alguns dados relevantes sobre essa anomalia
contrato_unmatch = {"header_mensalidade": [], "repasse": [], "tp_beneficiario": [], "marca_otica": [], "rubrica": []}
for i in df_h_m_r.index:    # contrato vem do header_mensalidade e cod_contrato do repasse
    if df_h_m_r["contrato"].at[i] != df_h_m_r["cod_contrato"].at[i]:
        contrato_unmatch["header_mensalidade"].append(df_h_m_r["contrato"].at[i])
        contrato_unmatch["repasse"].append(df_h_m_r["cod_contrato"].at[i])
        contrato_unmatch["tp_beneficiario"].append(df_h_m_r["tp_beneficiario"].at[i])
        contrato_unmatch["marca_otica"].append(i)
        contrato_unmatch["rubrica"].append(df_h_m_r["rubrica"].at[i])
        mongo_insert_one(df_h_m_r.loc[i].to_dict(), db=bd, col="dados_inconsistentes")
        df_h_m_r.drop(i, inplace=True)
contrato_unmatch
# Out:
# {'header_mensalidade': [],
#  'repasse': [],
#  'tp_beneficiario': [],
#  'marca_otica': [],
#  'rubrica': []}

# %%
df_h_m_r
# Out:
#                                 _id_x                   _idFile _lineNumber  \
# marca_otica
# 78372767     635b0aaf69a6ba7542168e06  630520e93299fb8245e2ee5d           3
# 
# 291238688    630521951e74c614e130cd93  ...          0      AMIL      84.0
# 291263194    630521951e74c614e130cd93  ...          0      AMIL      83.0
# 291285783    630521951e74c614e130cd93  ...          0      AMIL      82.0
# 291305148    62fffee77c45476c4844c3a7  ...          0      AMIL      81.0
# 291441203    62fffee77c45476c4844c3a7  ...          0      AMIL      75.0
# 291469272    62fffee77c45476c4844c3a7  ...          0      AMIL      74.0
# 852199546    630527e3bae0582dc78cfc3f  ...          0      AMIL      91.0
# 852308507    630527e3bae0582dc78cfc3f  ...          0      AMIL      89.0
#
#                                        plano_y   saude saude_net_orig  \
# marca_otica
# 78372767                GP3 - BLUE PLUS 500 QP   19179        1697.25
# 291052304               GP3 - BLUE PLUS 300 QC  208619        1846.20
# 291093370               GP3 - BLUE PLUS 300 QC  224206        1984.11
# 291139507               GP3 - BLUE PLUS 500 QP   32883        2910.02
# 291191630               GP3 - BLUE PLUS 500 QP  213979        1893.57
# 291214061               GP3 - BLUE PLUS 300 QC  405246        3586.30
# 291238688               GP3 - BLUE PLUS 300 QC  246615        2182.44
# 291263194               GP3 - BLUE PLUS 400 QP  265636        3898.29
# 291285783               GP3 - BLUE PLUS 600 QP  587321        5197.56
# 291305148    GP4 - AMIL 700 NACIONAL R PJCA QP  439883        3892.76
# 291441203    GP4 - AMIL 400 NACIONAL R PJCA QP  320292        2834.42
# 291469272    GP4 - AMIL 400 NACIONAL R PJCA QP  963378        8525.43
# 852199546               GP3 - BLUE PLUS 300 QP  169348        1498.64
# 852308507               GP3 - BLUE PLUS 300 QP  169348        1498.64
#
#             saude_orig  situacao  \
# marca_otica
# 78372767        1917.9     ATIVO
# 291052304      2086.19     ATIVO
# 291093370      2242.06   INATIVO
# 291139507       3288.3     ATIVO
# 291191630      2139.79     ATIVO
# 291214061      4052.46   INATIVO
# 291238688      2466.15     ATIVO
# 291263194      2656.36     ATIVO
# 291285783      5873.21     ATIVO
# 291305148      4398.83     ATIVO
# 291441203      3202.92   INATIVO
# 291469272      9633.78     ATIVO
# 852199546      1693.48     ATIVO
# 852308507      1693.48     ATIVO
#
#                                                         _idLog  \
# marca_otica
# 78372767     2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 291052304    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 291093370    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 291139507    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 291191630    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 291214061    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 291238688    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 291263194    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 291285783    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 291305148    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 291441203    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 291469272    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 852199546    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
# 852308507    2022-10-27_19-48-05.493131_6b867f6e-5649-11ed-...
#
#                              time_stamp
# marca_otica
# 78372767     2022-10-27 19:48:06.473955
# 291052304    2022-10-27 19:48:06.473955
# 291093370    2022-10-27 19:48:06.473955
# 291139507    2022-10-27 19:48:06.473955
# 291191630    2022-10-27 19:48:06.473955
# 291214061    2022-10-27 19:48:06.473955
# 291238688    2022-10-27 19:48:06.473955
# 291263194    2022-10-27 19:48:06.473955
# 291285783    2022-10-27 19:48:06.473955
# 291305148    2022-10-27 19:48:06.473955
# 291441203    2022-10-27 19:48:06.473955
# 291469272    2022-10-27 19:48:06.473955
# 852199546    2022-10-27 19:48:06.473955
# 852308507    2022-10-27 19:48:06.473955
#
# [14 rows x 55 columns]

# %%
# Analisa quem é dependente
dependentes = []
for i in df_h_m_r.index:
    if df_h_m_r["tp_beneficiario"].at[i] == "D":
        dependentes.append(i)
print(f"qtd: {len(dependentes)}")
dependentes
# Out:
# qtd: 2
# [78372767, 852199546]

# %%
# Apenas uma amostra
counter = 0
divergencias = {"valor_orig", "val"}
for i in df_h_m_r.index:
    if int(df_h_m_r["valor_orig"].at[i]) != int(df_h_m_r["saude_net_orig"].at[i]):
        #if "Capita" in df_h_m_r["rubrica"].at[i]:
        if df_h_m_r["tp_beneficiario"].at[i] == "D":
            print("$"*30)
        counter += 1
        #print(df_h_m_r.loc[i])
        print(f"marca otica          - {i}")
        print(f"rubrica              - {df_h_m_r['rubrica'].at[i]}")
        print(f"tipo de beneficiario - {df_h_m_r['tp_beneficiario'].at[i]}")
        print(f"contrato             - {df_h_m_r['contrato'].at[i]}")
        #print(f"outros              - {df_h_m_r['outros'].at[i]}")
        print(f"valor orig           - {int(df_h_m_r['valor_orig'].at[i])}")
        print(f"saude net orig       - {int(df_h_m_r['saude_net_orig'].at[i])}")
        print(f"situacao             - {df_h_m_r['situacao'].at[i]}")
        print(f"cancelamento         - {df_h_m_r['dt_cancelamento'].at[i]}")
        print(f"competencia          - {df_h_m_r['competencia'].at[i]}")
        print("-"*30)
print(counter)
# Out:
# marca otica          - 291093370
# rubrica              - Mens. Titular Faixa Etária Implant.
# tipo de beneficiario - T
# contrato             - 310572000
# valor orig           - 192
# saude net orig       - 1984
# situacao             - INATIVO
# cancelamento         - 2022-07-28 21:00:00
# competencia          - 2022-08-04 21:00:00
# ------------------------------
# marca otica          - 291214061
# rubrica              - Devolução Exclusão Retroativa
# tipo de beneficiario - T
# contrato             - 310572000
# valor orig           - -1388
# saude net orig       - 3586
# situacao             - INATIVO
# cancelamento         - 2022-07-17 21:00:00
# competencia          - 2022-08-04 21:00:00
# ------------------------------
# marca otica          - 291263194
# rubrica              - Mens. Titular Faixa Etária Implant.
# tipo de beneficiario - T
# contrato             - 310572000
# valor orig           - 4158
# saude net orig       - 3898
# situacao             - ATIVO
# cancelamento         - NaT
# competencia          - 2022-08-04 21:00:00
# ------------------------------
# marca otica          - 291285783
# rubrica              - Mens. Titular Faixa Etária Implant.
# tipo de beneficiario - T
# contrato             - 310572000
# valor orig           - 5198
# saude net orig       - 5197
# situacao             - ATIVO
# cancelamento         - NaT
# competencia          - 2022-08-04 21:00:00
# ------------------------------
# 4

# %%
# Identifica todos os casos conciliados e conciliados_com_div
df_h_m_r = df_h_m_r.reset_index()

bd = "cate"
matches = []
results = []
for i in df_h_m_r.index:
    if int(df_h_m_r["valor_orig"].at[i]) == int(df_h_m_r["saude_net_orig"].at[i]):
        #df_h_m_r.drop(i, inplace=True)
        matches.append(i)
        results.append("conciliado")
    elif df_h_m_r["valor_orig"].at[i] < 0 and "Retroativa" in df_h_m_r["rubrica"].at[i]:
        print(i)
        matches.append(i)
        results.append("conciliados")
    else:
        results.append("conciliados_com_div")
df_h_m_r["resultado"] = results
mongo_insert_many(df_h_m_r.to_dict("records"), db=bd, col="h_m_r_silver")
print(matches)
print(f"qtd: {len(matches)}")
# Out:
# 5
# [0, 1, 3, 4, 5, 6, 9, 10, 11, 12, 13]
# qtd: 11
